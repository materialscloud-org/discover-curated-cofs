# %%
# %matplotlib inline
from plot_isotherm import plot_isotherm
from query import get_data_aiida

label='13161N2'
# pm_co2 = load_node('23dd4dd8-f924-4232-984b-5f9efe288b70')
# pm_n2 = load_node('4709cfb1-2a90-4c70-a62d-a17305bc6021')
pm_co2 = get_data_aiida(structure_label=label, link_label='iso_co2')
pm_n2 = get_data_aiida(structure_label=label, link_label='iso_n2')
plot_isotherm(pm_co2=pm_co2, pm_n2=pm_n2, label=label)
