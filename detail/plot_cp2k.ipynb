# %%
from query import get_data_aiida
from plot_cp2k import plot_energy_steps

stepsfile=get_data_aiida(structure_label='13161N2', link_label='cp2k_stepsfile').get_file_abs_path()
plot_energy_steps(stepsfile, '13161N2')    

#plot_energy_steps('13161N2_test2-smearing_steps.out', '13161N2')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1049">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a54ab460-87a0-40b3-812e-904499620d3f" data-root-id="1003"></div>
